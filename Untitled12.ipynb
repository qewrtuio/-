# %%
import numpy as np
import pandas as pd
import os
os.chdir('C:/Users/user')
import matplotlib.pyplot as plt  #먼저 import 해주기
from matplotlib import font_manager, rc  #한글이 안나온다면 이렇게 끝까지 적어주깅
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
t_2019=pd.read_csv('time2019.csv',encoding='cp949')
t_2017=pd.read_csv('time2017.csv',encoding='cp949')
gender=pd.read_csv('gender.csv',encoding='cp949')
month=pd.read_csv('month.csv',encoding='cp949')

# %%
t_2019
# Out:
#        연령층      시간대  사고건수  사망자수  부상자수   중상   경상  부상신고
# 0    12세이하  00시-02시     5     0     9    5    2     2
# 1    12세이하  04시-06시     2     0     3    0    3     0
# 2    12세이하  06시-08시     7     0     9    2    3     4
# 3    12세이하  08시-10시    18     0    18    7    7     4
# 4    12세이하  10시-12시    15     0    16    6    8     2
# ..     ...      ...   ...   ...   ...  ...  ...   ...
# 102     불명  14시-16시   578     0   630  125  389   116
# 103     불명  16시-18시   769     1   845  161  547   137
# 104     불명  18시-20시   867     1  1018  204  684   130
# 105     불명  20시-22시   787     2   897  186  592   119
# 106     불명  22시-24시   707     1   812  185  526   101
#
# [107 rows x 8 columns]

# %%
age = t_2019["연령층"]

# %%
t_2017
# Out:
#        연령층      시간대  발생건수  사망자수  부상자수  중상   경상  부상신고
# 0    12세이하  00시-02시     1     0     1   1    0     0
# 1    12세이하  04시-06시     2     0     2   0    1     1
# 2    12세이하  06시-08시     1     0     1   1    0     0
# 3    12세이하  08시-10시    44     0    48  10   31     7
# 4    12세이하  10시-12시    28     0    28   4   14    10
# ..     ...      ...   ...   ...   ...  ..  ...   ...
# 102     불명  14시-16시   401     0   429  63  263   103
# 103     불명  16시-18시   480     0   511  68  326   117
# 104     불명  18시-20시   713     0   790  94  519   177
# 105     불명  20시-22시   581     0   657  86  428   143
# 106     불명  22시-24시   462     1   522  76  336   110
#
# [107 rows x 8 columns]

# %%
month
# Out:
#        연령층    월  발생건수  사망자수  부상자수  중상   경상  부상신고
# 0    12세이하  01월    11     0    11   3    6     2
# 1    12세이하  02월    14     0    15   1   12     2
# 2    12세이하  03월    37     1    38   6   22    10
# 3    12세이하  04월    64     0    66  14   37    15
# 4    12세이하  05월    78     0    84  19   42    23
# ..     ...  ...   ...   ...   ...  ..  ...   ...
# 103     불명  08월   373     0   423  71  258    94
# 104     불명  09월   412     0   459  76  280   103
# 105     불명  10월   421     0   467  56  304   107
# 106     불명  11월   402     0   444  75  276    93
# 107     불명  12월   412     0   459  64  307    88
#
# [108 rows x 8 columns]

# %%
gender
# Out:
#        연령층    성별   발생건수  사망자수   부상자수     중상     경상  부상신고
# 0    12세이하     남    549     2    579    119    309   151
# 1    12세이하     여     35     0     38     10     23     5
# 2   13-20세     남   7172   118  10125   2477   6288  1360
# 3   13-20세     여    413     4    670    136    489    45
# 4   13-20세  기타불명      6     0      6      1      5     0
# 5   21-30세     남  23971   457  37122   8417  26109  2596
# 6   21-30세     여   5281    47   8294   1778   6026   490
# 7   21-30세  기타불명      2     0      2      0      2     0
# 8   31-40세     남  25478   511  38966   9067  27312  2587
# 9   31-40세     여   8700    75  13128   2839   9480   809
# 10  31-40세  기타불명      1     0      1      0      1     0
# 11  41-50세     남  30914   608  46764  11777  32151  2836
# 12  41-50세     여  12751   131  19023   4533  13426  1064
# 13  41-50세  기타불명      3     0      3      0      2     1
# 14  51-60세     남  41567   915  62332  15519  43234  3579
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import matplotlib.font_manager as fm

# %%
plt.figure(figsize=(12,7))
plt.yticks([1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500])
plt.title('2017 event of age', size='30')
x=t_2017['연령층']
y=t_2017['발생건수']
plt.bar(x,y)
plt.show()

# %%
age
# Out:
# 0      12세이하
# 1      12세이하
# 2      12세이하
# 3      12세이하
# 4      12세이하
#        ...
# 102       불명
# 103       불명
# 104       불명
# 105       불명
# 106       불명
# Name: 연령층, Length: 107, dtype: object

# %%
t_2017[0:1]
# Out:
#      연령층      시간대  발생건수  사망자수  부상자수  중상  경상  부상신고
# 0  12세이하  00시-02시     1     0     1   1   0     0

# %%
t_2019[0:1]
# Out:
#      연령층      시간대  사고건수  사망자수  부상자수  중상  경상  부상신고
# 0  12세이하  00시-02시     5     0     9   5   2     2

# %%
gender[0:1]
# Out:
#      연령층 성별  발생건수  사망자수  부상자수   중상   경상  부상신고
# 0  12세이하  남   549     2   579  119  309   151

# %%
month[0:1]
# Out:
#      연령층    월  발생건수  사망자수  부상자수  중상  경상  부상신고
# 0  12세이하  01월    11     0    11   3   6     2

# %%
age12_2017 = t_2017[0:11]; age12_2017
# Out:
#       연령층      시간대  발생건수  사망자수  부상자수  중상  경상  부상신고
# 0   12세이하  00시-02시     1     0     1   1   0     0
# 1   12세이하  04시-06시     2     0     2   0   1     1
# 2   12세이하  06시-08시     1     0     1   1   0     0
# 3   12세이하  08시-10시    44     0    48  10  31     7
# 4   12세이하  10시-12시    28     0    28   4  14    10
# 5   12세이하  12시-14시    52     0    54  12  25    17
# 6   12세이하  14시-16시   137     1   142  30  77    35
# 7   12세이하  16시-18시   175     0   185  41  94    50
# 8   12세이하  18시-20시   112     1   120  24  70    26
# 9   12세이하  20시-22시    22     0    24   5  13     6
# 10  12세이하  22시-24시    10     0    12   1   7     4

# %%
plt.figure(figsize=(12,7))
plt.title('2017 event of time \n ~12')
plt.yticks([10, 30, 50, 70, 100, 150, 170, 180], size='15')
plt.xticks(size='13')
x=age12_2017['시간대']
y=age12_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
age10_2017 = t_2017[11:23]; age10_2017
# Out:
#        연령층      시간대  발생건수  사망자수  부상자수   중상    경상  부상신고
# 11  13-20세  00시-02시   546    14   859  227   540    92
# 12  13-20세  02시-04시   412    16   674  199   396    79
# 13  13-20세  04시-06시   316    24   491  150   295    46
# 14  13-20세  06시-08시   301     6   425  120   251    54
# 15  13-20세  08시-10시   405     4   572  131   367    74
# 16  13-20세  10시-12시   293     3   450   96   302    52
# 17  13-20세  12시-14시   449     3   641  131   424    86
# 18  13-20세  14시-16시   590     7   800  156   533   111
# 19  13-20세  16시-18시   937    10  1265  300   782   183
# 20  13-20세  18시-20시  1191    13  1612  353  1036   223
# 21  13-20세  20시-22시  1166    13  1574  402   931   241
# 22  13-20세  22시-24시   985     9  1438  349   925   164

# %%
plt.figure(figsize=(12,7))
plt.title('2017 event of time \n 13~20')
plt.yticks([300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200])
x=age10_2017['시간대']
y=age10_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
age20_2017 = t_2017[23:35]; age20_2017
# Out:
#        연령층      시간대  발생건수  사망자수  부상자수    중상    경상  부상신고
# 23  21-30세  00시-02시  2382    74  3855   931  2669   255
# 24  21-30세  02시-04시  1563    53  2490   587  1708   195
# 25  21-30세  04시-06시  1349    63  2100   556  1423   121
# 26  21-30세  06시-08시  1829    31  2716   636  1891   189
# 27  21-30세  08시-10시  2569    29  4022   864  2896   262
# 28  21-30세  10시-12시  1930    28  3018   681  2124   213
# 29  21-30세  12시-14시  2234    19  3597   777  2571   249
# 30  21-30세  14시-16시  2444    17  3808   751  2770   287
# 31  21-30세  16시-18시  2804    27  4470   964  3194   312
# 32  21-30세  18시-20시  3756    56  5605  1251  3995   359
# 33  21-30세  20시-22시  3162    32  4735  1069  3350   316
# 34  21-30세  22시-24시  3232    75  5002  1128  3546   328

# %%
plt.figure(figsize=(12,7))
plt.title('2017 event of time \n 21~30')
plt.yticks([1000, 1500, 2000, 2500, 3000, 3500, 4000])
x=age20_2017['시간대']
y=age20_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
age30_2017 = t_2017[35:47]; age30_2017
# Out:
#        연령층      시간대  발생건수  사망자수  부상자수    중상    경상  부상신고
# 35  31-40세  00시-02시  2181    67  3544   773  2534   237
# 36  31-40세  02시-04시  1198    60  1875   470  1285   120
# 37  31-40세  04시-06시  1013    57  1471   383   999    89
# 38  31-40세  06시-08시  1924    34  2846   718  1968   160
# 39  31-40세  08시-10시  3407    32  5024  1123  3606   295
# 40  31-40세  10시-12시  2776    46  4222   935  3043   244
# 41  31-40세  12시-14시  3191    33  5085  1174  3565   346
# 42  31-40세  14시-16시  3385    41  5224  1168  3672   384
# 43  31-40세  16시-18시  3875    37  5827  1362  4058   407
# 44  31-40세  18시-20시  4540    68  6723  1571  4664   488
# 45  31-40세  20시-22시  3556    58  5344  1194  3795   355
# 46  31-40세  22시-24시  3133    53  4910  1035  3604   271

# %%
plt.figure(figsize=(12,7))
plt.title('2017 event of time \n 31~40')
plt.yticks([1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000])
x=age30_2017['시간대']
y=age30_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
age40_2017 = t_2017[47:59]; age40_2017
# Out:
#        연령층      시간대  발생건수  사망자수  부상자수    중상    경상  부상신고
# 47  41-50세  00시-02시  2019    44  3198   798  2244   156
# 48  41-50세  02시-04시  1016    43  1534   432  1016    86
# 49  41-50세  04시-06시  1102    54  1609   491  1025    93
# 50  41-50세  06시-08시  2521    74  3740  1089  2410   241
# 51  41-50세  08시-10시  4670    53  6772  1717  4698   357
# 52  41-50세  10시-12시  3919    43  5971  1493  4084   394
# 53  41-50세  12시-14시  4247    44  6571  1615  4540   416
# 54  41-50세  14시-16시  4818    61  7381  1758  5136   487
# 55  41-50세  16시-18시  5335    67  8087  1989  5612   486
# 56  41-50세  18시-20시  5940   106  8717  2071  6161   485
# 57  41-50세  20시-22시  4556    88  6761  1618  4751   392
# 58  41-50세  22시-24시  3525    62  5449  1239  3902   308

# %%
plt.figure(figsize=(12,7))
plt.title('2017 event of time \n 41~50')
plt.yticks([1000, 2000, 3000, 4000, 5000, 6000])
x=age40_2017['시간대']
y=age40_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
age50_2017 = t_2017[59:71]; age50_2017
# Out:
#        연령층      시간대  발생건수  사망자수   부상자수    중상    경상  부상신고
# 59  51-60세  00시-02시  2253    75   3552   852  2486   214
# 60  51-60세  02시-04시  1181    43   1910   483  1312   115
# 61  51-60세  04시-06시  1420    68   2099   622  1321   156
# 62  51-60세  06시-08시  3334    97   4778  1409  3070   299
# 63  51-60세  08시-10시  5367    74   7936  1984  5463   489
# 64  51-60세  10시-12시  5286    93   7827  2027  5356   444
# 65  51-60세  12시-14시  5203    85   8037  1933  5689   415
# 66  51-60세  14시-16시  6043   104   9137  2234  6410   493
# 67  51-60세  16시-18시  7011   101  10434  2559  7288   587
# 68  51-60세  18시-20시  7341   139  10913  2521  7804   588
# 69  51-60세  20시-22시  5212   100   7748  1843  5464   441
# 70  51-60세  22시-24시  3761    87   5701  1316  4039   346

# %%
plt.figure(figsize=(12,7))
plt.title('2017 event of time \n 51~60')
plt.yticks([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000])
plt.ylabel("event")
x=age50_2017['시간대']
y=age50_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
age60_2017 = t_2017[71:83]; age60_2017
# Out:
#        연령층      시간대  발생건수  사망자수  부상자수   중상    경상  부상신고
# 71  61-64세  00시-02시   629    12   969  278   634    57
# 72  61-64세  02시-04시   360    10   569  151   388    30
# 73  61-64세  04시-06시   493    19   661  201   409    51
# 74  61-64세  06시-08시  1037    31  1480  439   963    78
# 75  61-64세  08시-10시  1772    25  2548  651  1751   146
# 76  61-64세  10시-12시  1740    35  2521  650  1744   127
# 77  61-64세  12시-14시  1710    27  2549  640  1757   152
# 78  61-64세  14시-16시  1982    32  2983  724  2103   156
# 79  61-64세  16시-18시  2155    40  3277  773  2319   185
# 80  61-64세  18시-20시  2071    37  3066  731  2165   170
# 81  61-64세  20시-22시  1418    29  2230  499  1599   132
# 82  61-64세  22시-24시  1008    20  1506  343  1081    82

# %%
plt.figure(figsize=(12,7))
plt.title('2017 event of time \n 61~64')
plt.yticks([300, 500, 700, 900, 1100, 1300, 1500, 1700, 1900, 2100])
x=age60_2017['시간대']
y=age60_2017['발생건수']
plt.grid()
plt.bar(x,y)
plt.show()

# %%
age65_2017 = t_2017[83:95]; age65_2017
# Out:
#       연령층      시간대  발생건수  사망자수  부상자수    중상    경상  부상신고
# 83  65세이상  00시-02시   616    17   907   233   600    74
# 84  65세이상  02시-04시   350    18   526   132   362    32
# 85  65세이상  04시-06시   781    65  1092   373   653    66
# 86  65세이상  06시-08시  1675    60  2268   703  1433   132
# 87  65세이상  08시-10시  3276   101  4643  1317  2995   331
# 88  65세이상  10시-12시  3701   115  5304  1513  3492   299
# 89  65세이상  12시-14시  3473   103  5122  1348  3422   352
# 90  65세이상  14시-16시  3747   108  5414  1477  3595   342
# 91  65세이상  16시-18시  3599    95  5363  1340  3724   299
# 92  65세이상  18시-20시  2921    92  4188  1084  2849   255
# 93  65세이상  20시-22시  1619    49  2445   610  1674   161
# 94  65세이상  22시-24시   955    25  1355   342   936    77

# %%
plt.figure(figsize=(12,7))
plt.title('2017 시간대에 따른 발생건수 \n 65세 이상')
plt.yticks([300, 600, 900, 1200, 1500, 1800, 2400, 2700, 3000, 3300, 3600])
x=age65_2017['시간대']
y=age65_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
ageNaN_2017 = t_2017[95:107]; ageNaN_2017
# Out:
#     연령층      시간대  발생건수  사망자수  부상자수  중상   경상  부상신고
# 95   불명  00시-02시   278     0   330  53  209    68
# 96   불명  02시-04시   182     0   217  36  142    39
# 97   불명  04시-06시   175     0   201  31  127    43
# 98   불명  06시-08시   249     0   271  56  171    44
# 99   불명  08시-10시   391     0   413  57  247   109
# 100  불명  10시-12시   295     0   333  50  213    70
# 101  불명  12시-14시   352     0   376  53  246    77
# 102  불명  14시-16시   401     0   429  63  263   103
# 103  불명  16시-18시   480     0   511  68  326   117
# 104  불명  18시-20시   713     0   790  94  519   177
# 105  불명  20시-22시   581     0   657  86  428   143
# 106  불명  22시-24시   462     1   522  76  336   110

# %%
plt.figure(figsize=(12,7))
plt.title('2017년 시간대에 따른 발생건수 \n 측정불가')
plt.yticks([100, 200, 300, 400, 500, 600, 700, 800])
x=ageNaN_2017['시간대']
y=ageNaN_2017['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
man = gender[gender['성별'] == '남']

# %%
woman = gender[gender['성별'] == '여']

# %%
ew = woman['발생건수']
total1 = ew.sum()
total1
# Out:
# 44145

# %%
em = man['발생건수']
total2 = em.sum()
total2
# Out:
# 167572

# %%
ratio = [total2, total1]   
labels = ['남자', '여자']   
explode = (0.0, 0.1) 
colors = ['gold', 'lightskyblue'] 
plt.pie(ratio, explode=explode, labels=labels, colors=colors, startangle=90, autopct='%1.1f%%')
plt.title('성별에 따른 발생건수')
plt.show()

# %%
month.head(2)
# Out:
#      연령층    월  발생건수  사망자수  부상자수  중상  경상  부상신고
# 0  12세이하  01월    11     0    11   3   6     2
# 1  12세이하  02월    14     0    15   1  12     2

# %%
month1 = month[month['월'] == '01월']
month2 = month[month['월'] == '02월']
month3 = month[month['월'] == '03월']
month4 = month[month['월'] == '04월']
month5 = month[month['월'] == '05월']
month6 = month[month['월'] == '06월']
month7 = month[month['월'] == '07월']
month8 = month[month['월'] == '08월']
month9 = month[month['월'] == '09월']
month10 = month[month['월'] == '10월']
month11 = month[month['월'] == '11월']
month12 = month[month['월'] == '12월']

# %%
plt.figure(figsize=(12,7))
plt.title('월에따른 발생건수 \n 1월')
plt.yticks([1000, 2000, 3000, 4000, 5000])
plt.ylabel("발생건수")
x=month1['연령층']
y=month1['발생건수']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
em1 = month1['발생건수']
em2 = month2['발생건수']
em3 = month3['발생건수']
em4 = month4['발생건수']
em5 = month5['발생건수']
em6 = month6['발생건수']
em7 = month7['발생건수']
em8 = month8['발생건수']
em9 = month9['발생건수']
em10 = month10['발생건수']
em11 = month11['발생건수']
em12 = month12['발생건수']
sum1 = em1.sum()
sum2 = em2.sum()
sum3 = em3.sum()
sum4 = em4.sum()
sum5 = em5.sum()
sum6 = em6.sum()
sum7 = em7.sum()
sum8 = em8.sum()
sum9 = em9.sum()
sum10 = em10.sum()
sum11 = em11.sum()
sum12 = em12.sum()

# %%
df = pd.DataFrame({'month': ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'], 
                  'event': [sum1, sum2, sum3, sum4, sum5, sum6, sum7, sum8, sum9, sum10, sum11, sum12]})
df
# Out:
#    month  event
# 0     1월  16970
# 1     2월  14832
# 2     3월  17047
# 3     4월  17717
# 4     5월  18502
# 5     6월  18047
# 6     7월  18158
# 7     8월  18682
# 8     9월  19891
# 9    10월  18863
# 10   11월  19377
# 11   12월  18249

# %%
plt.figure(figsize=(12,7))
plt.title('월에따른 발생건수')
plt.yticks([10000, 13000, 15000, 17000, 19000, 21000])
plt.ylabel("발생건수")
x=df['month']
y=df['event']
plt.bar(x,y)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,7))  
plt.title('월에따른 발생건수 \n 1월')  
plt.yticks([10000, 13000, 15000, 17000, 19000, 21000])  
plt.ylabel("발생건수")  
x=month1['연령층']  
y=month1['발생건수'] 
plt.bar(x,y)  
plt.grid()   
plt.show()
