# %%
import numpy as np
import pandas as pd
import os
os.chdir('C:/Users/user')
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc 
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
car=pd.read_csv('car.csv',encoding='cp949')
month_2016=pd.read_csv('month2016.csv',encoding='cp949')
rule=pd.read_csv('rule.csv',encoding='cp949')
road=pd.read_csv('road.csv',encoding='cp949')
age=pd.read_csv('age.csv', encoding='cp949')

# %%
car.head(2)
# Out:
#   사고유형대분류 사고유형  차종   발생건수
# 0    차대사람  횡단중  경형  14122
# 1    차대사람  횡단중  소형   6322

# %%
month_2016.head(2)
# Out:
#   사고유형대분류 사고유형    월  발생건수
# 0    차대사람  횡단중  01월  2278
# 1    차대사람  횡단중  02월  2048

# %%
age.head(2)
# Out:
#   사고유형대분류 사고유형      연령  발생건수
# 0    차대사람  횡단중   12세이하    40
# 1    차대사람  횡단중  13-20세  1085

# %%
rule.head(2)
# Out:
#   사고유형대분류 사고유형    법규위반  발생건수
# 0    차대사람  횡단중      과속   152
# 1    차대사람  횡단중  중앙선 침범   314

# %%
road.head(2)
# Out:
#   사고유형대분류 사고유형  도로종류  발생건수
# 0    차대사람  횡단중  일반국도  1075
# 1    차대사람  횡단중   지방도  1904

# %%
fig = plt.figure( figsize = (60, 50))   # 차대사람
palette = sns.color_palette("Blues")
sns.set_palette(palette, len(car))
plt.subplot(3, 2, 1)
sns.barplot(car.loc[0:9, '차종'], car.loc[0:9, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(car.loc[10:19, '차종'], car.loc[10:19, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(car.loc[20:29, '차종'], car.loc[20:29, '발생건수'])
plt.title('길가장자리 구역 통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(car.loc[30:39, '차종'], car.loc[30:39, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(car.loc[40:49, '차종'], car.loc[40:49, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   #차대차
palette = sns.color_palette("BuGn")
sns.set_palette(palette, len(car))
plt.subplot(2, 2, 1)
sns.barplot(car.loc[50:59, '차종'], car.loc[50:59, '발생건수'])
plt.title('정면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 2)
sns.barplot(car.loc[60:69, '차종'], car.loc[60:69, '발생건수'])
plt.title('측면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 3)
sns.barplot(car.loc[70:79, '차종'], car.loc[70:79, '발생건수'])
plt.title('추돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 4)
sns.barplot(car.loc[80:89, '차종'], car.loc[80:89, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
fig.suptitle('차대차', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   #차량단독
palette = sns.color_palette("BuPu")
sns.set_palette(palette, len(car))
plt.subplot(3, 2, 1)
sns.barplot(car.loc[90:99, '차종'], car.loc[90:99, '발생건수'])
plt.title('전도전복', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(car.loc[100:109, '차종'], car.loc[100:109, '발생건수'])
plt.title('공작물충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(car.loc[110:115, '차종'], car.loc[110:115, '발생건수'])
plt.title('주/정차 차량 충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(car.loc[116:125, '차종'], car.loc[116:125, '발생건수'])
plt.title('도로이탈', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(car.loc[126:135, '차종'], car.loc[126:135, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차량단독', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("GnBu")
sns.set_palette(palette, len(car))
sns.barplot(car.loc[136:138, '차종'], car.loc[136:138, '발생건수'])  #철길건널목
plt.title('철길건널목 \n기타', fontsize=20)
plt.show()

# %%
car1 = car.loc[0:9, '발생건수'].sum()   #차대사람
car2 = car.loc[10:19, '발생건수'].sum()
car3 = car.loc[20:29, '발생건수'].sum()
car4 = car.loc[30:39, '발생건수'].sum()
car5 = car.loc[40:49, '발생건수'].sum()
car6 = car.loc[50:59, '발생건수'].sum()
car7 = car.loc[60:69, '발생건수'].sum()
car8 = car.loc[70:79, '발생건수'].sum()
car9 = car.loc[80:89, '발생건수'].sum()
car10 = car.loc[90:99, '발생건수'].sum()
car11= car.loc[100:109, '발생건수'].sum()
car12 = car.loc[110:115, '발생건수'].sum()
car13 = car.loc[116:125, '발생건수'].sum()
car14 = car.loc[126:135, '발생건수'].sum()
car15 = car.loc[136:138, '발생건수'].sum()

# %%
cp = pd.DataFrame({'type': ['횡단중', '차도통행중', '길가장자리', '보도통행중', '기타'],
                  'event': [car1, car2, car3, car4, car5]})
cp
# Out:
#     type  event
# 0    횡단중  33884
# 1  차도통행중   3622
# 2  길가장자리   3544
# 3  보도통행중   1627
# 4     기타  14743

# %%
cc = pd.DataFrame({'type': ['정면충돌', '측면충돌', '추돌', '기타'],
                  'event': [car6, car7, car8, car9]})
cc
# Out:
#    type  event
# 0  정면충돌  19498
# 1  측면충돌  73397
# 2    추돌  41003
# 3    기타  28091

# %%
co = pd.DataFrame({'type': ['전도전복', '공작물충돌', '주/정차 차량충돌', '도로이탈','기타'],
                  'event': [car10, car11, car12, car13, car14]})
co
# Out:
#         type  event
# 0       전도전복   4834
# 1      공작물충돌   2160
# 2  주/정차 차량충돌     36
# 3       도로이탈    261
# 4         기타   3100

# %%
palette = sns.color_palette("bright")
sns.set_palette("pastel")
fig = plt.figure( figsize = (10, 10))   #유형별 발생건수
plt.subplot(1, 3, 1)
ratio = [car1, car5, car3, car4, car2]   
labels = ['횡단중', '기타', '길가장자리', '보도통행중', '차도통행중']   
colors = ['yellow', 'lightskyblue', 'salmon', 'plum', 'greenyellow'] 
plt.pie(ratio, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('차대사람 유형별 발생건수')
plt.subplot(1, 3, 2)
ratio = [car6, car7, car8, car9]   
labels = ['정면충돌', '측면충돌', '추돌', '기타']   
colors = ['yellow', 'lightskyblue', 'plum', 'greenyellow'] 
plt.pie(ratio, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('차대차 유형별 발생건수')
plt.subplot(1, 3, 3)
ratio = [car10, car11, car14, car13, car12]   
labels = ['전도전복', '공작물충돌', '기타', '도로이탈', '주/정차 차량충돌']   
colors = ['yellow', 'lightskyblue', 'greenyellow', 'plum', 'salmon'] 
plt.pie(ratio, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('차량단독 유형별 발생건수')

fig.suptitle('\n \n \n \n \n사고유형별 발생건수', fontsize=30)
plt.show()

# %%
fe = pd.DataFrame({'type': ['기타'],
                  'event': [car15]})
fe
# Out:
#   type  event
# 0   기타      6

# %%
fig = plt.figure( figsize = (60, 50))   # 차대사람
palette = sns.color_palette("Greens")
sns.set_palette(palette)
plt.subplot(2, 2, 1)
sns.barplot(cp.type, cp.event)
plt.title('차대사람', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 2)
sns.barplot(cc.type, cc.event)
plt.title('차대차', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 3)
sns.barplot(co.type, co.event)
plt.title('길가장자리 구역 통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 4)
sns.barplot(fe.type, fe.event)
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('사고유형별 발생건수', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   # 차대사람
palette = sns.color_palette("OrRd")
sns.set_palette(palette, len(rule))
plt.subplot(3, 2, 1)
sns.barplot(rule.loc[0:7, '법규위반'], rule.loc[0:7, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(rule.loc[8:15, '법규위반'], rule.loc[8:15, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(rule.loc[16:23, '법규위반'], rule.loc[16:23, '발생건수'])
plt.title('길가장자리 구역 통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(rule.loc[24:31, '법규위반'], rule.loc[24:31, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(rule.loc[32:39, '법규위반'], rule.loc[32:39, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   # 차대차
palette = sns.color_palette("PuBu")
sns.set_palette(palette, len(rule))
plt.subplot(2, 2, 1)
sns.barplot(rule.loc[40:47, '법규위반'], rule.loc[40:47, '발생건수'])
plt.title('정면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 2)
sns.barplot(rule.loc[48:55, '법규위반'], rule.loc[48:55, '발생건수'])
plt.title('측면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 3)
sns.barplot(rule.loc[56:63, '법규위반'], rule.loc[56:63, '발생건수'])
plt.title('추돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 4)
sns.barplot(rule.loc[64:71, '법규위반'], rule.loc[64:71, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대차', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   # 차량단독 해야함!!!!!!!!!!!!!!!!!!!!!!
palette = sns.color_palette("PuBuGn")
sns.set_palette(palette, len(rule))
plt.subplot(3, 2, 1)
sns.barplot(rule.loc[72:78, '법규위반'], rule.loc[72:78, '발생건수'])
plt.title('전도전복', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(rule.loc[79:85, '법규위반'], rule.loc[79:85, '발생건수'])
plt.title('공작물충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(rule.loc[86:88, '법규위반'], rule.loc[86:88, '발생건수'])
plt.title('주/정차 차량 충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(rule.loc[89:94, '법규위반'], rule.loc[89:94, '발생건수'], ci=None)
plt.title('도로이탈', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(rule.loc[95:101, '법규위반'], rule.loc[95:101, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차량단독', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("PuRd")
sns.set_palette(palette, len(rule))
sns.barplot(rule.loc[102:103, '법규위반'], rule.loc[102:103, '발생건수'])  #철길건널목
plt.title('철길건널목 \n기타', fontsize=20)
plt.show()

# %%
fig = plt.figure( figsize = (30, 40))   # 차대사람
palette = sns.color_palette("Purples")
sns.set_palette(palette, len(road))
plt.subplot(3, 2, 1)
sns.barplot(road.loc[0:6, '도로종류'], road.loc[0:6, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(road.loc[7:13, '도로종류'], road.loc[7:13, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(road.loc[14:20, '도로종류'], road.loc[14:20, '발생건수'])
plt.title('길가장자리', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(road.loc[21:27, '도로종류'], road.loc[21:27, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(road.loc[28:34, '도로종류'], road.loc[28:34, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("RdPu")
sns.set_palette(palette, len(road))
fig = plt.figure( figsize = (60, 50))   # 차대차
plt.subplot(3, 2, 1)
sns.barplot(road.loc[35:41, '도로종류'], road.loc[35:41, '발생건수'])
plt.title('정면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(road.loc[42:48, '도로종류'], road.loc[42:48, '발생건수'])
plt.title('측면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(road.loc[49:55, '도로종류'], road.loc[49:55, '발생건수'])
plt.title('추돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(road.loc[56:62, '도로종류'], road.loc[56:62, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대차', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("YlGn")
sns.set_palette(palette, len(road))
fig = plt.figure( figsize = (30, 40))   # 차량단독
plt.subplot(3, 2, 1)
sns.barplot(road.loc[63:69, '도로종류'], road.loc[63:69, '발생건수'])
plt.title('전도전복', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(road.loc[70:76, '도로종류'], road.loc[70:76, '발생건수'])
plt.title('공작물충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(road.loc[77:81, '도로종류'], road.loc[77:81, '발생건수'])
plt.title('주/정차차량 충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(road.loc[82:95, '도로종류'], road.loc[82:95, '발생건수'], ci=None)
plt.title('도로이탈', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(road.loc[96:102, '도로종류'], road.loc[96:102, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
fig.suptitle('차량단독', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("bright")
sns.set_palette("pastel")
sns.barplot(road.loc[103:105, '도로종류'], road.loc[103:105, '발생건수'])  #철길건널목
plt.title('철길건널목 \n기타', fontsize=20)
plt.show()

# %%
r1 = road[road['도로종류'] == '일반국도']
s1 = r1['발생건수'].sum()

r2 = road[road['도로종류'] == '지방도']
s2 = r2['발생건수'].sum()

r3 = road[road['도로종류'] == '특별광역시도']
s3 = r3['발생건수'].sum()

r4 = road[road['도로종류'] == '시도']
s4 = r4['발생건수'].sum()

r5 = road[road['도로종류'] == '군도']
s5 = r5['발생건수'].sum()

r6 = road[road['도로종류'] == '고속국도']
s6 = r6['발생건수'].sum()

r7 = road[road['도로종류'] == '기타']
s7 = r7['발생건수'].sum()

# %%
df1 = pd.DataFrame({'road': ['일반국도', '지방도', '특별광역시도', '시도', '군도', '고속국도', '기타'],
                   'event': [s1, s2, s3, s4, s5, s6, s7]})
df1
# Out:
#      road  event
# 0    일반국도  16959
# 1     지방도  18223
# 2  특별광역시도  87685
# 3      시도  71433
# 4      군도   7194
# 5    고속국도   4347
# 6      기타  15076

# %%
ratio = [s1, s2, s3, s4, s5, s6, s7]   
labels = ['일반국도', '지방도', '특별광역시도', '시도', '군도', '고속국도', '기타']   
colors = ['yellow', 'lightskyblue', 'salmon', 'plum', 'greenyellow', 'orange', 'lightseagreen'] 
plt.pie(ratio, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('도로 유형별 발생건수')
plt.show()

# %%
palette = sns.color_palette("YlGnBu")
sns.set_palette(palette, len(df1.road))
sns.barplot(df1.road, df1.event)  #도로유형 합          #원그래프 그리기
plt.title('도로유형별 발생건수', fontsize=20)
plt.show()

# %%
fig = plt.figure( figsize = (50, 40))   # 차대사람
palette = sns.color_palette("YlOrBr")
sns.set_palette(palette, len(age))
plt.subplot(3, 2, 1)
sns.barplot(age.loc[0:8, '연령'], age.loc[0:8, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(age.loc[9:17, '연령'], age.loc[9:17, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(age.loc[18:26, '연령'], age.loc[18:26, '발생건수'])
plt.title('길가장자리', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(age.loc[27:35, '연령'], age.loc[27:35, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(age.loc[36:44, '연령'], age.loc[36:44, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (50, 40))   # 차대차
palette = sns.color_palette("PRGn")
sns.set_palette(palette, len(age))
plt.subplot(3, 2, 1)
sns.barplot(age.loc[45:53, '연령'], age.loc[45:53, '발생건수'])
plt.title('정면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(age.loc[54:62, '연령'], age.loc[54:62, '발생건수'])
plt.title('측면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(age.loc[63:71, '연령'], age.loc[63:71, '발생건수'])
plt.title('추돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(age.loc[72:80, '연령'], age.loc[72:80, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대차', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("PiYG")
sns.set_palette(palette, len(car))
fig = plt.figure( figsize = (50, 40))   # 차대사람
plt.subplot(3, 2, 1)
sns.barplot(age.loc[81:89, '연령'], age.loc[81:89, '발생건수'])
plt.title('전도전복', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(age.loc[90:98, '연령'], age.loc[90:98, '발생건수'])
plt.title('공작물충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(age.loc[99:105, '연령'], age.loc[99:105, '발생건수'])
plt.title('주/정차차량 충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(age.loc[106:120, '연령'], age.loc[106:120, '발생건수'], ci=None)
plt.title('도로이탈', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(age.loc[121:129, '연령'], age.loc[121:129, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차량단독', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("bright")
sns.set_palette("pastel")
sns.barplot(age.loc[130:133, '연령'], age.loc[130:133, '발생건수'])  #철길건널목
plt.title('철길건널목 \n기타', fontsize=20)
plt.show()

# %%
a1 = age[age['연령'] == '12세이하']
p1 = a1['발생건수'].sum()

a2 = age[age['연령'] == '13-20세']
p2 = a2['발생건수'].sum()

a3 = age[age['연령'] == '21-30세']
p3 = a3['발생건수'].sum()

a4 = age[age['연령'] == '31-40세']
p4 = a4['발생건수'].sum()

a5 = age[age['연령'] == '41-50세']
p5 = a5['발생건수'].sum()

a6 = age[age['연령'] == '51-60세']
p6 = a6['발생건수'].sum()

a7 = age[age['연령'] == '61-64세']
p7 = a7['발생건수'].sum()

a8 = age[age['연령'] == '65세이상']
p8=a8['발생건수'].sum()

a9 = age[age['연령']=='불명']
p9=a9['발생건수'].sum()

# %%
df2 = pd.DataFrame({'age': ['12세이하', '13-20세', '21-30세', '31-40세', '41-50세', '51-60세', '61-64세','65세이상','불명'],
                   'event': [p1, p2, p3, p4, p5, p6, p7,p8,p9]})
df2
# Out:
#       age  event
# 0   12세이하    489
# 1  13-20세   8517
# 2  21-30세  29797
# 3  31-40세  35900
# 4  41-50세  47219
# 5  51-60세  54299
# 6  61-64세  15305
# 7   65세이상  24429
# 8      불명   4962

# %%
fig = plt.figure(figsize=(20, 20))
ratio = [p1, p2, p3, p4, p5, p6, p7, p8, p9]  
explode = [0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02, 0.02]
labels = ['12세이하', '13~20세', '21~30세', '31~40세', '41~50세', '51~60세', '61~64세', '65세이상', '불명']   
colors = sns.color_palette('BuPu', len(labels))
plt.pie(ratio, labels=labels,explode=explode, colors=colors, autopct='%1.1f%%', textprops={'fontsize': 30})
plt.title('나이 별 발생건수', fontsize=20)
# Out:
# Text(0.5, 1.0, '나이 별 발생건수')

# %%
palette = sns.color_palette("BuPu")
sns.set_palette(palette, len(df2.age))
sns.barplot(df2.age, df2.event)  #나이 합          #원그래프 그리기
plt.title('나이 별 발생건수', fontsize=20)
plt.show()

# %%
a1 = age[age['연령'] == '12세이하']
a1
# Out:
#     사고유형대분류        사고유형     연령  발생건수
# 0      차대사람         횡단중  12세이하    40
# 9      차대사람       차도통행중  12세이하     6
# 18     차대사람  길가장자리구역통행중  12세이하     4
# 27     차대사람       보도통행중  12세이하    11
# 36     차대사람          기타  12세이하    47
# 45      차대차        정면충돌  12세이하    48
# 54      차대차        측면충돌  12세이하   222
# 63      차대차          추돌  12세이하    14
# 72      차대차          기타  12세이하    88
# 81     차량단독        전도전복  12세이하     3
# 90     차량단독       공작물충돌  12세이하     1
# 121    차량단독          기타  12세이하     5

# %%
m1 = month_2016[month_2016['월'] == '01월']['발생건수'].sum()
m2 = month_2016[month_2016['월'] == '02월']['발생건수'].sum()
m3 = month_2016[month_2016['월'] == '03월']['발생건수'].sum()
m4 = month_2016[month_2016['월'] == '04월']['발생건수'].sum()
m5 = month_2016[month_2016['월'] == '05월']['발생건수'].sum()
m6 = month_2016[month_2016['월'] == '06월']['발생건수'].sum()
m7 = month_2016[month_2016['월'] == '07월']['발생건수'].sum()
m8 = month_2016[month_2016['월'] == '08월']['발생건수'].sum()
m9 = month_2016[month_2016['월'] == '09월']['발생건수'].sum()
m10 = month_2016[month_2016['월'] == '10월']['발생건수'].sum()
m11 = month_2016[month_2016['월'] == '11월']['발생건수'].sum()
m12 = month_2016[month_2016['월'] == '12월']['발생건수'].sum()

# %%
df3 = pd.DataFrame({'month': ['01월', '02월', '03월', '04월', '05월', '06월', '07월','08월','09월', '10월', '11월', '12월'],
                   'event': [m1, m2, m3, m4, m5, m6, m7, m8, m9, m10, m11, m12]})
df3
# Out:
#    month  event
# 0    01월  17067
# 1    02월  15664
# 2    03월  17946
# 3    04월  19452
# 4    05월  19554
# 5    06월  17977
# 6    07월  18955
# 7    08월  18398
# 8    09월  17883
# 9    10월  19918
# 10   11월  19234
# 11   12월  18869

# %%
sns.barplot(df3.month, df3.event)  #월 합          #원그래프 그리기
plt.title('월 별 발생건수', fontsize=20)
plt.show()

# %%
plt.plot(df3.month, df3.event, marker = 'o', markersize =8, color = 'black', linewidth=4)  #월 합          #원그래프 그리기
plt.title('월 별 발생건수', fontsize=20)
plt.show()

# %%
fig = plt.figure( figsize = (30, 40))   # 차대사람
palette = sns.color_palette("bright")
sns.set_palette(palette)
plt.subplot(3, 2, 1)
sns.barplot(month_2016.loc[0:11, '월'], month_2016.loc[0:11, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(month_2016.loc[12:23, '월'], month_2016.loc[12:23, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(month_2016.loc[24:35, '월'], month_2016.loc[24:35, '발생건수'])
plt.title('길가장자리', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(month_2016.loc[36:47, '월'], month_2016.loc[36:47, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(month_2016.loc[48:59, '월'], month_2016.loc[48:59, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (30, 40))   # 차대차
palette = sns.color_palette("bright")
sns.set_palette(palette)
plt.subplot(3, 2, 1)
sns.barplot(month_2016.loc[60:71, '월'], month_2016.loc[60:71, '발생건수'])
plt.title('정면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(month_2016.loc[72:83, '월'], month_2016.loc[72:83, '발생건수'])
plt.title('측면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(month_2016.loc[84:95, '월'], month_2016.loc[84:95, '발생건수'])
plt.title('추돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(month_2016.loc[96:107, '월'], month_2016.loc[96:107, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대차', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (30, 40))   # 차대단독
palette = sns.color_palette("bright")
sns.set_palette(palette)
plt.subplot(3, 2, 1)
sns.barplot(month_2016.loc[108:119, '월'], month_2016.loc[108:119, '발생건수'])
plt.title('전도전복', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
sns.barplot(month_2016.loc[120:131, '월'], month_2016.loc[120:131, '발생건수'])
plt.title('공작물충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
sns.barplot(month_2016.loc[132:143, '월'], month_2016.loc[132:143, '발생건수'])
plt.title('주/정차차량 충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
sns.barplot(month_2016.loc[144:167, '월'], month_2016.loc[144:167, '발생건수'], ci=None)
plt.title('도로이탈', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
sns.barplot(month_2016.loc[168:179, '월'], month_2016.loc[168:179, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차량단독', fontsize=100)
plt.show()

# %%
palette = sns.color_palette("bright")
sns.set_palette("pastel")
sns.barplot(month_2016.loc[180:183, '월'], month_2016.loc[180:183, '발생건수'])  #철길건널목
plt.title('철길건널목 \n기타', fontsize=20)
plt.show()
